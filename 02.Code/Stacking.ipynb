# %%
import pandas as pd
import os
import numpy as np
import sys
module_path = "../src"
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.utils import seed_everything
from sklearn.metrics import mean_absolute_error
from utils.boosting import Training_Lightgbm
from utils.encoding import ClassicEncoding
# General Parameters
MODEL_PATH  = '../03.SavedModels'
MODEL_NAMES = ['baseline_lstm_v7','baseline_lstm_v14','baseline_lstm_v15']
SEED        = 42

# %%
def feat_eng(df):
    # Add Feature engineering df:
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    df['cross']= df['u_in']*df['u_out']
    df['cross2']= df['time_step']*df['u_out']
    df['R_indx'] = df['R']
    df['C_indx'] = df['C']
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    return df

# %%
# %%time 
# Training:
train_df = pd.read_csv('../01.Data/train_folds.csv')
train_df = feat_eng(train_df)
train_df = train_df[train_df['u_out']==0].reset_index(drop = True)
for name in MODEL_NAMES:
    train_df = train_df.merge(pd.read_csv(os.path.join(MODEL_PATH,name,'oof_preds.csv')).rename(columns = {'oof':'preds'}),how = 'left',on = ['id','breath_id'])
# Out:
# CPU times: user 28.7 s, sys: 12 s, total: 40.7 s
# Wall time: 41.3 s

# %%
drop_cols   = ['id','breath_id','R_indx','C_indx']
columns_modeling = ['preds','pressure','u_in_cumsum','fold']#train_df.drop(columns = drop_cols).columns.to_list()
cat_columns = [i for i in train_df.columns if 'label' in i]
params = {
        'task': 'train',
        'boosting_type': 'gbdt',
        'objective': 'huber',
        'alpha'    :0.2, 
        'metric':  'mae',
        'num_leaves':64,
        'learning_rate': 0.1,
        #"min_child_samples": 300,
        "max_depth" : 8,
        'feature_fraction':  0.75,
        "bagging_freq": 1,
        'bagging_fraction': 0.75,
        #'num_threads':18,
        #"scale_pos_weight":5 -> Generally  is the ratio of number of negative class to the positive class.
        'bagging_seed':SEED,
        'lambda_l1':1,
        'lambda_l2':1,
        'verbose': 1

}

results,models,importances,oof,feature_list = Training_Lightgbm(train_df[columns_modeling],
                                                                params,
                                                                fold_column = 'fold',
                                                                target_column = 'pressure',
                                                                cat_vars = cat_columns,
                                                                metric = 'MAE', 
                                                                early_stopping = 200, 
                                                                max_boost_round = 8000*2)
# Out:
# Columns: ['preds', 'u_in_cumsum']
# Cat index: []
# ---------- Training fold Nº 1 ----------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1832862, number of used features: 2
# [LightGBM] [Info] Start training from score 17.605154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 200 rounds
# [50]	training's l1: 7.01293	valid_1's l1: 7.01286
# [100]	training's l1: 6.44891	valid_1's l1: 6.45483
# [150]	training's l1: 5.93404	valid_1's l1: 5.94517
# [200]	training's l1: 5.46741	valid_1's l1: 5.48324
# [250]	training's l1: 5.04505	valid_1's l1: 5.06512
# [300]	training's l1: 4.66484	valid_1's l1: 4.68873
# [350]	training's l1: 4.3256	valid_1's l1: 4.3523
# [400]	training's l1: 4.03198	valid_1's l1: 4.06094
# [450]	training's l1: 3.78687	valid_1's l1: 3.81753
# [500]	training's l1: 3.58661	valid_1's l1: 3.61836
# [550]	training's l1: 3.4324	valid_1's l1: 3.46515
# [600]	training's l1: 3.34651	valid_1's l1: 3.37957
# [650]	training's l1: 3.29409	valid_1's l1: 3.3272
# [700]	training's l1: 3.255	valid_1's l1: 3.28792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's l1: 3.22406	valid_1's l1: 3.25709
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's l1: 3.1986	valid_1's l1: 3.23226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's l1: 3.17737	valid_1's l1: 3.21197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's l1: 3.16029	valid_1's l1: 3.19586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's l1: 3.14698	valid_1's l1: 3.18365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's l1: 3.13625	valid_1's l1: 3.17373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's l1: 3.12742	valid_1's l1: 3.16538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's l1: 3.11997	valid_1's l1: 3.15827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1150]	training's l1: 3.11377	valid_1's l1: 3.15233
# [1200]	training's l1: 3.10855	valid_1's l1: 3.14728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1250]	training's l1: 3.10419	valid_1's l1: 3.14308
# [1300]	training's l1: 3.1003	valid_1's l1: 3.13934
# [1350]	training's l1: 3.09716	valid_1's l1: 3.13636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1400]	training's l1: 3.09454	valid_1's l1: 3.1339
# [1450]	training's l1: 3.0922	valid_1's l1: 3.13173
# [1500]	training's l1: 3.09007	valid_1's l1: 3.12979
# [1550]	training's l1: 3.08841	valid_1's l1: 3.12826
# [1600]	training's l1: 3.08712	valid_1's l1: 3.12705
# [1650]	training's l1: 3.08611	valid_1's l1: 3.12608
# [1700]	training's l1: 3.08529	valid_1's l1: 3.12532
# [1750]	training's l1: 3.08463	valid_1's l1: 3.12474
# [1800]	training's l1: 3.08408	valid_1's l1: 3.12429
# [1850]	training's l1: 3.08362	valid_1's l1: 3.1239
# [1900]	training's l1: 3.08322	valid_1's l1: 3.12359
# [1950]	training's l1: 3.08289	valid_1's l1: 3.12333
# [2000]	training's l1: 3.08259	valid_1's l1: 3.1231
# [2050]	training's l1: 3.08233	valid_1's l1: 3.12291
# [2100]	training's l1: 3.0821	valid_1's l1: 3.12276
# [2150]	training's l1: 3.0819	valid_1's l1: 3.12262
# [2200]	training's l1: 3.08173	valid_1's l1: 3.1225
# [2250]	training's l1: 3.08158	valid_1's l1: 3.1224
# [2300]	training's l1: 3.08144	valid_1's l1: 3.12232
# [2350]	training's l1: 3.08133	valid_1's l1: 3.12224
# [2400]	training's l1: 3.08122	valid_1's l1: 3.12218
# [2450]	training's l1: 3.08113	valid_1's l1: 3.12212
# [2500]	training's l1: 3.08105	valid_1's l1: 3.12207
# [2550]	training's l1: 3.08098	valid_1's l1: 3.12203
# [2600]	training's l1: 3.08092	valid_1's l1: 3.12199
# [2650]	training's l1: 3.08086	valid_1's l1: 3.12196
# [2700]	training's l1: 3.08081	valid_1's l1: 3.12194
# [2750]	training's l1: 3.08076	valid_1's l1: 3.12191
# [2800]	training's l1: 3.08072	valid_1's l1: 3.12189
# [2850]	training's l1: 3.08068	valid_1's l1: 3.12187
# [2900]	training's l1: 3.08064	valid_1's l1: 3.12185
# [2950]	training's l1: 3.08061	valid_1's l1: 3.12184
# [3000]	training's l1: 3.08058	valid_1's l1: 3.12183
# [3050]	training's l1: 3.08055	valid_1's l1: 3.12181
# [3100]	training's l1: 3.08052	valid_1's l1: 3.1218
# [3150]	training's l1: 3.0805	valid_1's l1: 3.1218
# [3200]	training's l1: 3.08048	valid_1's l1: 3.12179
# [3250]	training's l1: 3.08046	valid_1's l1: 3.12179
# [3300]	training's l1: 3.08044	valid_1's l1: 3.12179
# [3350]	training's l1: 3.08042	valid_1's l1: 3.12178
# [3400]	training's l1: 3.0804	valid_1's l1: 3.12178
# [3450]	training's l1: 3.08038	valid_1's l1: 3.12178
# [3500]	training's l1: 3.08037	valid_1's l1: 3.12177
# [3550]	training's l1: 3.08035	valid_1's l1: 3.12177
# [3600]	training's l1: 3.08034	valid_1's l1: 3.12177
# [3650]	training's l1: 3.08033	valid_1's l1: 3.12178
# Early stopping, best iteration is:
# [3476]	training's l1: 3.08038	valid_1's l1: 3.12177
# Train MAE: 3.0803751637719192        Valida MAE: 3.1217730124759795
# Columns: ['preds', 'u_in_cumsum']
# Cat index: []
# ---------- Training fold Nº 2 ----------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004767 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 510
# [LightGBM] [Info] Number of data points in the train set: 1832856, number of used features: 2
# [LightGBM] [Info] Start training from score 17.607797
# Training until validation scores don't improve for 200 rounds
# [50]	training's l1: 7.01952	valid_1's l1: 6.99205
# [100]	training's l1: 6.45786	valid_1's l1: 6.42826
# [150]	training's l1: 5.94506	valid_1's l1: 5.91385
# [200]	training's l1: 5.48008	valid_1's l1: 5.44829
# [250]	training's l1: 5.05905	valid_1's l1: 5.02689
# [300]	training's l1: 4.67999	valid_1's l1: 4.64737
# [350]	training's l1: 4.34136	valid_1's l1: 4.30865
# [400]	training's l1: 4.04818	valid_1's l1: 4.01565
# [450]	training's l1: 3.80307	valid_1's l1: 3.77071
# [500]	training's l1: 3.60247	valid_1's l1: 3.57073
# [550]	training's l1: 3.44779	valid_1's l1: 3.41721
# [600]	training's l1: 3.36139	valid_1's l1: 3.33189
# [650]	training's l1: 3.30839	valid_1's l1: 3.28038
# [700]	training's l1: 3.26856	valid_1's l1: 3.2425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [750]	training's l1: 3.2371	valid_1's l1: 3.2132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [800]	training's l1: 3.2112	valid_1's l1: 3.18944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [850]	training's l1: 3.1896	valid_1's l1: 3.16993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	training's l1: 3.17227	valid_1's l1: 3.1541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	training's l1: 3.15891	valid_1's l1: 3.14163
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	training's l1: 3.14811	valid_1's l1: 3.13161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1050]	training's l1: 3.13919	valid_1's l1: 3.12334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1100]	training's l1: 3.13165	valid_1's l1: 3.11642
# [1150]	training's l1: 3.12537	valid_1's l1: 3.11069
# [1200]	training's l1: 3.12003	valid_1's l1: 3.10579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1250]	training's l1: 3.11561	valid_1's l1: 3.1017
# [1300]	training's l1: 3.11166	valid_1's l1: 3.09805
# [1350]	training's l1: 3.10841	valid_1's l1: 3.09507
# [1400]	training's l1: 3.10576	valid_1's l1: 3.09269
# [1450]	training's l1: 3.10342	valid_1's l1: 3.09061
# [1500]	training's l1: 3.10127	valid_1's l1: 3.08873
# [1550]	training's l1: 3.09945	valid_1's l1: 3.08712
# [1600]	training's l1: 3.09806	valid_1's l1: 3.08591
# [1650]	training's l1: 3.09696	valid_1's l1: 3.08497
# [1700]	training's l1: 3.0961	valid_1's l1: 3.0842
# [1750]	training's l1: 3.09541	valid_1's l1: 3.08358
# [1800]	training's l1: 3.09484	valid_1's l1: 3.08308
# [1850]	training's l1: 3.09436	valid_1's l1: 3.08265
# [1900]	training's l1: 3.09395	valid_1's l1: 3.0823
# [1950]	training's l1: 3.09359	valid_1's l1: 3.082
# [2000]	training's l1: 3.09327	valid_1's l1: 3.08172
# [2050]	training's l1: 3.09299	valid_1's l1: 3.0815
# [2100]	training's l1: 3.09274	valid_1's l1: 3.0813
# [2150]	training's l1: 3.09252	valid_1's l1: 3.08113
# [2200]	training's l1: 3.09232	valid_1's l1: 3.08098
# [2250]	training's l1: 3.09215	valid_1's l1: 3.08086
# [2300]	training's l1: 3.092	valid_1's l1: 3.08076
# [2350]	training's l1: 3.09186	valid_1's l1: 3.08067
# [2400]	training's l1: 3.09174	valid_1's l1: 3.0806
# [2450]	training's l1: 3.09163	valid_1's l1: 3.08054
# [2500]	training's l1: 3.09154	valid_1's l1: 3.08048
# [2550]	training's l1: 3.09145	valid_1's l1: 3.08044
# [2600]	training's l1: 3.09137	valid_1's l1: 3.0804
# [2650]	training's l1: 3.0913	valid_1's l1: 3.08038
# [2700]	training's l1: 3.09123	valid_1's l1: 3.08036
# [2750]	training's l1: 3.09117	valid_1's l1: 3.08034
# [2800]	training's l1: 3.09112	valid_1's l1: 3.08033
# [2850]	training's l1: 3.09107	valid_1's l1: 3.08032
# [2900]	training's l1: 3.09102	valid_1's l1: 3.08031
# [2950]	training's l1: 3.09098	valid_1's l1: 3.0803
# [3000]	training's l1: 3.09094	valid_1's l1: 3.0803
# [3050]	training's l1: 3.09091	valid_1's l1: 3.0803
# [3100]	training's l1: 3.09088	valid_1's l1: 3.0803
# [3150]	training's l1: 3.09085	valid_1's l1: 3.0803
# [3200]	training's l1: 3.09082	valid_1's l1: 3.0803
# [3250]	training's l1: 3.09079	valid_1's l1: 3.0803
# Early stopping, best iteration is:
# [3053]	training's l1: 3.09091	valid_1's l1: 3.0803
